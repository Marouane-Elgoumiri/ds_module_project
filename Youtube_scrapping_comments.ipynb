# %% [markdown]
# <a href="https://colab.research.google.com/github/Marouane-Elgoumiri/ds_module_project/blob/main/Youtube_scrapping_comments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dev = "you key here"

# %% [markdown]
# ## Pull All Comments

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="SXjIYRih13I",
    maxResults=100
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="SXjIYRih13I", maxResults=100, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      183 non-null    object
#  1   updated_at  183 non-null    object
#  2   like_count  183 non-null    int64
#  3   text        183 non-null    object
#  4   public      183 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 6.0+ KB

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'Kn03h72Pqu48_fraTXDmYyShdGw',
#  'id': 'UgwRGRJykotUZVrhRBp4AaABAg',
#  'snippet': {'channelId': 'UChz9LmLfA1Q2SCx32fYw-Og',
#   'videoId': 'SXjIYRih13I',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'YpSG7h1e4yT342uOOOSGVLAhVKk',
#    'id': 'UgwRGRJykotUZVrhRBp4AaABAg',
#    'snippet': {'channelId': 'UChz9LmLfA1Q2SCx32fYw-Og',
#     'videoId': 'SXjIYRih13I',
#     'textDisplay': 'Rust or bust!',
#     'textOriginal': 'Rust or bust!',
#     'authorDisplayName': '@nad9969',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_miueajLU11EHkqG1OlN6K_Zvf7Xvd87E00sFK71yyqDuY=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@nad9969',
#     'authorChannelId': {'value': 'UCI9gvP2tZfxukUvjibY8CVA'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2024-02-01T03:14:49Z',
#     'updatedAt': '2024-02-01T03:14:49Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %%
df.head(10)
# Out:
#                     author            updated_at  like_count  \
# 0           @JasonGoodison  2024-01-14T16:53:28Z          53
# 1        @brianfreeman2200  2024-05-08T05:41:26Z           0
# 2              @always9155  2024-05-08T00:44:38Z           0
# 3               @tuanphvng  2024-05-01T12:08:15Z           2
# 4       @williambreeze2659  2024-04-30T13:03:32Z           0
# 5                  @DB42YT  2024-04-28T06:53:07Z           0
# 6              @Omar-cw5gg  2024-04-24T16:33:11Z           0
# 7         @RoastLambShanks  2024-04-22T07:38:18Z           1
# 8         @ArticulateArena  2024-04-18T01:53:59Z           1
# 9  @TheInterestingInformer  2024-04-14T07:55:46Z           0
#
#                                                 text  public
# 0  System.out.printLn("Sorry about the delay in u...    True
# 1  Hi Jason. I want to learn everything that I ca...    True
# 2                     Bro this mic is killing me 🤣🤣🤣    True
# 3  this guy was yapping for 15 mins for absolutel...    True
# 4                                   Thanks for this!    True
# 5  I was skeptical but there are some useful obse...    True
# 6                  9:43 What did you mean by cycles?    True
# 7           It's not a function noob, it's a method.    True
# 8  Ok. So this made me blow up my computer and mo...    True
# 9                  This was actually well produced 🔥    True

# %% [markdown]
# ## Sort by Likes and Get Top 10

# %%
df.sort_values(by='like_count', ascending=False)[0:10]
# Out:
#                   author            updated_at  like_count  \
# 120         @ballman4288  2024-01-25T21:40:59Z         293
# 60      @InfectiousViper  2024-02-14T05:13:18Z          96
# 117      @justincase8532  2024-01-27T00:27:14Z          78
# 139           @xeliotrop  2024-01-22T13:10:02Z          55
# 140        @efficientapp  2024-01-22T00:08:38Z          55
# 0         @JasonGoodison  2024-01-14T16:53:28Z          53
# 178       @JasonGoodison  2024-01-14T16:53:28Z          53
# 179  @cody_codes_youtube  2024-01-14T16:47:21Z          28
# 48         @ExiledDelver  2024-02-23T15:00:01Z          23
# 130   @davidfilestra8826  2024-01-23T15:38:47Z          17
#
#                                                   text  public
# 120  Main takeaway: Don't just learn frameworks, un...    True
# 60                              15 minutes of nothing.    True
# 117  I do feel sorry for young programmers these da...    True
# 139  You know the video is off when they call React...    True
# 140  Watched this twice. Once myself and again with...    True
# 0    System.out.printLn("Sorry about the delay in u...    True
# 178  System.out.printLn("Sorry about the delay in u...    True
# 179  Oh wow dude. This is such a well done video! W...    True
# 48   Oh my god dude, I almost fell out of my chair ...    True
# 130  this is fantastic, it never ends, so many usel...    True

# %% [markdown]
# #Pull all Comments for Multiple Videos

# %% [markdown]
# ## 1. Get Comments Function

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)


def getcomments(video):
  request = youtube.commentThreads().list(
      part="snippet",
      videoId=video,
      maxResults=100
  )

  comments = []

  # Execute the request.
  response = request.execute()

  # Get the comments from the response.
  for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  while (1 == 1):
    try:
     nextPageToken = response['nextPageToken']
    except KeyError:
     break
    nextPageToken = response['nextPageToken']
    # Create a new request object with the next page token.
    nextRequest = youtube.commentThreads().list(part="snippet", videoId=video, maxResults=100, pageToken=nextPageToken)
    # Execute the next request.
    response = nextRequest.execute()
    # Get the comments from the next response.
    for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  df2 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','video_id','public'])
  return df2

# %%
df = getcomments('TYxqBTdOq24')
df
# Out:
#                 author            updated_at  like_count  \
# 0               yaohun  2023-09-08T05:43:51Z           0
# 1       Cedric Goodwin  2023-06-08T07:21:41Z           0
# 2  Analytics with Adam  2023-05-10T06:12:50Z           1
#
#                                                 text     video_id  public
# 0  Hi, sorry I am very new to SAP dashboard and h...  TYxqBTdOq24    True
# 1                                         ⭐ Promo_SM  TYxqBTdOq24    True
# 2  Interested in thoughts on SAC compared with Po...  TYxqBTdOq24    True

# %% [markdown]
# ## 2. For Loop for List of IDs

# %%
df = pd.DataFrame()
for i in ['QOcP5OvSwlI','Lfzu74XDyco','TiS6vnju_mI','cYwioeHu_OU']:
  df2 = getcomments(i)
  df = pd.concat([df, df2])

# %%
df
# Out:
#                  author            updated_at  like_count  \
# 0        Artur Nawrocki  2023-10-27T06:28:00Z           0
# 1        Bostjan Brumec  2023-10-27T06:23:00Z           0
# 2       Esteban Herrera  2023-10-27T04:12:19Z           0
# 3                Jyothi  2023-10-27T02:07:35Z           0
# 4            Anil Ameer  2023-10-26T19:42:54Z           0
# ..                  ...                   ...         ...
# 440  sameer vishwakarma  2022-06-30T11:17:57Z           0
# 441       Adam Sikorski  2022-06-30T11:13:33Z           0
# 442  Unq.Universalfacts  2022-06-30T11:09:16Z           0
# 443         Ahmed Tareq  2022-06-30T11:04:25Z           0
# 444     Jonathan CHANAL  2022-06-30T11:03:35Z           0
#
#                                                   text     video_id  public
# 0    SVG visuals has taken LinkedIn by storm. Too l...  QOcP5OvSwlI    True
# 1    Very inspiring! Maybe it can be used to create...  QOcP5OvSwlI    True
# 2                                   As always excelent  QOcP5OvSwlI    True
# 3    Thanks Bas, for the video. Could you kindly te...  QOcP5OvSwlI    True
# 4    Take notes 📝  Microsoft, you are not listening...  QOcP5OvSwlI    True
# ..                                                 ...          ...     ...
# 440                                               Cool  cYwioeHu_OU    True
# 441                                 Ok that looks dope  cYwioeHu_OU    True
# 442  Amazing.. Thanks a lot .. Can you plz share da...  cYwioeHu_OU    True
# 443                                                  🤩  cYwioeHu_OU    True
# 444                    Realy nice design! well done ;)  cYwioeHu_OU    True
#
# [966 rows x 6 columns]

# %%
df['video_id'].value_counts()
# Out:
# cYwioeHu_OU    445
# Lfzu74XDyco    371
# TiS6vnju_mI    100
# QOcP5OvSwlI     50
# Name: video_id, dtype: int64
